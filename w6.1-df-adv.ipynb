# %% [markdown]
# - apply
# - datetimes
# - group
# - agg

# %%
import pandas as pd
df = pd.read_csv("./data/french-ambs.csv")
df.head()
# Out:
#    id                name    place  year    lat   long      lat_long
# 0   0  Richer, Christophe  Denmark  1543  55.68  12.57  55.68, 12.57
# 1   1  Richer, Christophe  Denmark  1541  55.68  12.57  55.68, 12.57
# 2   2  Danzay, Charles de  Denmark  1561  55.68  12.57  55.68, 12.57
# 3   3  Danzay, Charles de  Denmark  1563  55.68  12.57  55.68, 12.57
# 4   4  Danzay, Charles de  Denmark  1582  55.68  12.57  55.68, 12.57

# %%
from random import choice
# import random
# random.choice 
df["date_start"] = f"{df["year"]}-{choice(range(1,13)):02d}-{choice(range(1,29)):02d}"
df.head()
# Out:
#    id                name    place  year    lat   long      lat_long  \
# 0   0  Richer, Christophe  Denmark  1543  55.68  12.57  55.68, 12.57
# 1   1  Richer, Christophe  Denmark  1541  55.68  12.57  55.68, 12.57
# 2   2  Danzay, Charles de  Denmark  1561  55.68  12.57  55.68, 12.57
# 3   3  Danzay, Charles de  Denmark  1563  55.68  12.57  55.68, 12.57
# 4   4  Danzay, Charles de  Denmark  1582  55.68  12.57  55.68, 12.57
#
#                                           date_start
# 0  0      1543\n1      1541\n2      1561\n3      ...
# 1  0      1543\n1      1541\n2      1561\n3      ...
# 2  0      1543\n1      1541\n2      1561\n3      ...
# 3  0      1543\n1      1541\n2      1561\n3      ...
# 4  0      1543\n1      1541\n2      1561\n3      ...

# %%
df = df.drop(columns=["date_start","lat_long"])
df = df[["name", "place", "year"]]
df.head()
# Out:
#                  name    place  year
# 0  Richer, Christophe  Denmark  1543
# 1  Richer, Christophe  Denmark  1541
# 2  Danzay, Charles de  Denmark  1561
# 3  Danzay, Charles de  Denmark  1563
# 4  Danzay, Charles de  Denmark  1582

# %%
# apply on data series
def my_function(x):
    return x

df["date_start"] = df["year"].apply(lambda x: f"{x}-{choice(range(1,13)):02d}-{choice(range(1,29)):02d}")
df.head()
# Out:
#                  name    place  year  date_start
# 0  Richer, Christophe  Denmark  1543  1543-03-04
# 1  Richer, Christophe  Denmark  1541  1541-04-16
# 2  Danzay, Charles de  Denmark  1561  1561-11-05
# 3  Danzay, Charles de  Denmark  1563  1563-04-12
# 4  Danzay, Charles de  Denmark  1582  1582-09-24

# %%
import numpy as np
def get_date_start(row):
    rows = df.loc[
        (df["place"] == row["place"]) &
        (df["name"] == row["name"]) &
        (df["year"] == row["year"] - 1)
    ]
    if len(rows) > 0: # len(rows) > 0
        return np.nan
        
    date_string = f"{row['year']}-{choice(range(1,13)):02d}-{choice(range(1,29)):02d}"
    return date_string

df["date_start"] = df.apply(get_date_start, axis=1)
df.head()
# Out:
#                  name    place  year  date_start
# 0  Richer, Christophe  Denmark  1543         NaN
# 1  Richer, Christophe  Denmark  1541  1541-02-09
# 2  Danzay, Charles de  Denmark  1561         NaN
# 3  Danzay, Charles de  Denmark  1563         NaN
# 4  Danzay, Charles de  Denmark  1582         NaN

# %%
def get_date_end(row):
    rows = df.loc[
        (df["place"] == row["place"]) &
        (df["name"] == row["name"]) &
        (df["year"] == row["year"] + 1)
    ]
    if len(rows) > 0: # len(rows) > 0
        return np.nan
        
    date_string = f"{row['year']}-{choice(range(1,13)):02d}-{choice(range(1,29)):02d}"
    return date_string

df["date_end"] = df.apply(get_date_end, axis=1)
df.head()
# Out:
#                  name    place  year  date_start date_end
# 0  Richer, Christophe  Denmark  1543         NaN      NaN
# 1  Richer, Christophe  Denmark  1541  1541-02-09      NaN
# 2  Danzay, Charles de  Denmark  1561         NaN      NaN
# 3  Danzay, Charles de  Denmark  1563         NaN      NaN
# 4  Danzay, Charles de  Denmark  1582         NaN      NaN

# %%
# bfill(), ffill() but first sort values appropiately
df = df.sort_values(["place", "name", "year"], ascending=True)
df
# Out:
#                     name    place  year  date_start    date_end
# 422   Danzay, Charles de  Denmark  1557  1557-05-03         NaN
# 638   Danzay, Charles de  Denmark  1558         NaN         NaN
# 704   Danzay, Charles de  Denmark  1559         NaN         NaN
# 421   Danzay, Charles de  Denmark  1560         NaN         NaN
# 2     Danzay, Charles de  Denmark  1561         NaN         NaN
# ..                   ...      ...   ...         ...         ...
# 112     Séguier, Antoine   Venice  1599         NaN         NaN
# 531     Séguier, Antoine   Venice  1600         NaN  1600-09-01
# 353  d'Armagnac, Georges   Venice  1536  1536-09-18         NaN
# 756  d'Armagnac, Georges   Venice  1537         NaN         NaN
# 757  d'Armagnac, Georges   Venice  1538         NaN  1538-03-09
#
# [869 rows x 5 columns]

# %%
from datetime import datetime
fmt = "%Y-%m-%d"

df["date_end"] = df["date_end"]. apply(lambda x: datetime.strptime(x, fmt))
df["date_start"] = df["date_start"]. apply(lambda x: datetime.strptime(x, fmt))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 4
#       1 from datetime import datetime
#       2 fmt = "%Y-%m-%d"
# ----> 4 df["date_end"] = df["date_end"]. apply(lambda x: datetime.strptime(x, fmt))
#       5 df["date_start"] = df["date_start"]. apply(lambda x: datetime.strptime(x, fmt))
#
# File /opt/anaconda3/envs/PythonClass/lib/python3.13/site-packages/pandas/core/series.py:4943, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4808 def apply(
#    4809     self,
#    4810     func: AggFuncType,
#    (...)   4815     **kwargs,
#    4816 ) -> DataFrame | Series:
#    4817     """
#    4818     Invoke function on values of Series.
#    4819
#    (...)   4934     dtype: float64
#    4935     """
#    4936     return SeriesApply(
#    4937         self,
#    4938         func,
#    4939         convert_dtype=convert_dtype,
#    4940         by_row=by_row,
#    4941         args=args,
#    4942         kwargs=kwargs,
# -> 4943     ).apply()
#
# File /opt/anaconda3/envs/PythonClass/lib/python3.13/site-packages/pandas/core/apply.py:1422, in SeriesApply.apply(self)
#    1419     return self.apply_compat()
#    1421 # self.func is Callable
# -> 1422 return self.apply_standard()
#
# File /opt/anaconda3/envs/PythonClass/lib/python3.13/site-packages/pandas/core/apply.py:1502, in SeriesApply.apply_standard(self)
#    1496 # row-wise access
#    1497 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1498 # we need to give `na_action="ignore"` for categorical data.
#    1499 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1500 #  Categorical (GH51645).
#    1501 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1502 mapped = obj._map_values(
#    1503     mapper=curried, na_action=action, convert=self.convert_dtype
#    1504 )
#    1506 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1507     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1508     #  See also GH#25959 regarding EA support
#    1509     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File /opt/anaconda3/envs/PythonClass/lib/python3.13/site-packages/pandas/core/base.py:925, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     922 if isinstance(arr, ExtensionArray):
#     923     return arr.map(mapper, na_action=na_action)
# --> 925 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File /opt/anaconda3/envs/PythonClass/lib/python3.13/site-packages/pandas/core/algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File pandas/_libs/lib.pyx:2999, in pandas._libs.lib.map_infer()
#
# Cell In[56], line 4, in <lambda>(x)
#       1 from datetime import datetime
#       2 fmt = "%Y-%m-%d"
# ----> 4 df["date_end"] = df["date_end"]. apply(lambda x: datetime.strptime(x, fmt))
#       5 df["date_start"] = df["date_start"]. apply(lambda x: datetime.strptime(x, fmt))
#
# TypeError: strptime() argument 1 must be str, not float

# %%
placesdf = df.groupby(["place"]).count()

# %%
placesdf = df.groupby(["place"]).agg(
    {
        "name": "count",
        "year": ["min", "max"],
    }
).reset_index()
placesdf
# Out:
#                 place  name  year
#                       count   min   max
# 0             Denmark    40  1541  1589
# 1             England    93  1516  1600
# 2             Ferrara     3  1535  1554
# 3              Geneva     2  1559  1560
# 4             Grisons    77  1525  1588
# 5   Holy Roman Empire    81  1519  1600
# 6         Netherlands    45  1529  1600
# 7      Ottoman Empire    89  1535  1600
# 8              Poland     7  1572  1574
# 9            Portugal    56  1522  1578
# 10               Rome    82  1513  1589
# 11              Savoy     4  1528  1574
# 12             Saxony     3  1570  1572
# 13           Scotland    22  1548  1588
# 14              Spain    35  1559  1589
# 15      Swiss Cantons   131  1522  1600
# 16            Tuscany     3  1527  1529
# 17             Venice    96  1516  1600

# %%
placesdf = df.groupby("place").agg(
    num=("year", "count"),
    min_year=("year", "min"),
    max_year=("year", "max"),
    ambs=("name", "unique"),
    num_ambs=("name", "nunique"),
).sort_values(["num"]).reset_index()
placesdf
# Out:
#                 place  num  min_year  max_year  \
# 0             Denmark   40      1541      1589
# 1             England   93      1516      1600
# 2             Ferrara    3      1535      1554
# 3              Geneva    2      1559      1560
# 4             Grisons   77      1525      1588
# 5   Holy Roman Empire   81      1519      1600
# 6         Netherlands   45      1529      1600
# 7      Ottoman Empire   89      1535      1600
# 8              Poland    7      1572      1574
# 9            Portugal   56      1522      1578
# 10               Rome   82      1513      1589
# 11              Savoy    4      1528      1574
# 12             Saxony    3      1570      1572
# 13           Scotland   22      1548      1588
# 14              Spain   35      1559      1589
# 15      Swiss Cantons  131      1522      1600
# 16            Tuscany    3      1527      1529
# 17             Venice   96      1516      1600
#
#                                                  ambs  num_ambs
# 0            [Danzay, Charles de, Richer, Christophe]         2
# 1   [Bapaume, Robert de, Bochetel, Jacques, Castel...        26
# 2             [Du Gabre, Dominique, Langeac, Jean de]         2
# 3                       [Boistaillé, Jean Hurault de]         1
# 4   [Bellièvre, Pomponne de, Cambray, Jean-Jacques...        13
# 5   [Ancel, Guillaume, Bochetel, Bernardin, Calvim...        15
# 6   [Blatier, Claude, Bochetel, Jacques, Choary, P...        12
# 7   [Berthier, Sébastien, Cambray, Jacques de, Cot...        20
# 8   [Fayes, Jacques, sr d'Espesses, Lansac, Guy de...         5
# 9   [De Caix, Honoré, De Seurre, Miguel, Nicot, Je...         5
# 10  [Adhemar, Louis, Babou, Philibert, Carmain, Pa...        24
# 11  [Des Barres, Louis, Henri d'Angouleme, Sr. de ...         3
# 12                            [Schomberg, Gaspard de]         1
# 13  [Clutin, Henri, Courcelles, Baron de, Du Croc,...         4
# 14  [Fourquevaux, Raymond de Beccarie de Pavie, Ba...         5
# 15  [Bellièvre, Jean de, sr. de Hautefort, Bellièv...        27
# 16                                   [Dodieu, Claude]         1
# 17  [Boistaillé, Jean Hurault de, Canossa, Louis d...        20

# %%
place_names = df.groupby("place").agg(
    num=("year", "count"),
    min_year=("year", "min"),
    max_year=("year", "max"),
    ambs=("name", "unique"),
    num_ambs=("name", "nunique"),
).reset_index().sort_values(["num"])
place_names
# Out:
#                 place  num  min_year  max_year  \
# 3              Geneva    2      1559      1560
# 2             Ferrara    3      1535      1554
# 12             Saxony    3      1570      1572
# 16            Tuscany    3      1527      1529
# 11              Savoy    4      1528      1574
# 8              Poland    7      1572      1574
# 13           Scotland   22      1548      1588
# 14              Spain   35      1559      1589
# 0             Denmark   40      1541      1589
# 6         Netherlands   45      1529      1600
# 9            Portugal   56      1522      1578
# 4             Grisons   77      1525      1588
# 5   Holy Roman Empire   81      1519      1600
# 10               Rome   82      1513      1589
# 7      Ottoman Empire   89      1535      1600
# 1             England   93      1516      1600
# 17             Venice   96      1516      1600
# 15      Swiss Cantons  131      1522      1600
#
#                                                  ambs  num_ambs
# 3                       [Boistaillé, Jean Hurault de]         1
# 2             [Du Gabre, Dominique, Langeac, Jean de]         2
# 12                            [Schomberg, Gaspard de]         1
# 16                                   [Dodieu, Claude]         1
# 11  [Des Barres, Louis, Henri d'Angouleme, Sr. de ...         3
# 8   [Fayes, Jacques, sr d'Espesses, Lansac, Guy de...         5
# 13  [Clutin, Henri, Courcelles, Baron de, Du Croc,...         4
# 14  [Fourquevaux, Raymond de Beccarie de Pavie, Ba...         5
# 0            [Danzay, Charles de, Richer, Christophe]         2
# 6   [Blatier, Claude, Bochetel, Jacques, Choary, P...        12
# 9   [De Caix, Honoré, De Seurre, Miguel, Nicot, Je...         5
# 4   [Bellièvre, Pomponne de, Cambray, Jean-Jacques...        13
# 5   [Ancel, Guillaume, Bochetel, Bernardin, Calvim...        15
# 10  [Adhemar, Louis, Babou, Philibert, Carmain, Pa...        24
# 7   [Berthier, Sébastien, Cambray, Jacques de, Cot...        20
# 1   [Bapaume, Robert de, Bochetel, Jacques, Castel...        26
# 17  [Boistaillé, Jean Hurault de, Canossa, Louis d...        20
# 15  [Bellièvre, Jean de, sr. de Hautefort, Bellièv...        27
